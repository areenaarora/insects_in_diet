# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
df = pd.read_csv('data/protein-per-capita.csv')
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df.sort_values(by=['Value'])
# Out:
#      Domain Code                 Domain  Area Code  \
# 471          FBS  Food Balances (2010-)         29
# 470          FBS  Food Balances (2010-)         29
# 466          FBS  Food Balances (2010-)         29
# 469          FBS  Food Balances (2010-)         29
# 467          FBS  Food Balances (2010-)         29
# 468          FBS  Food Balances (2010-)         29
# 908          FBS  Food Balances (2010-)        250
# 910          FBS  Food Balances (2010-)        250
# 911          FBS  Food Balances (2010-)        250
# 909          FBS  Food Balances (2010-)        250
# 905          FBS  Food Balances (2010-)        250
# 904          FBS  Food Balances (2010-)        250
# 907          FBS  Food Balances (2010-)        250
# 903          FBS  Food Balances (2010-)        250
# 902          FBS  Food Balances (2010-)        250
# 906          FBS  Food Balances (2010-)        250
# 2202         FBS  Food Balances (2010-)        144
# ...

# %%
from plotnine import *
import numpy as np

# %%
(
    ggplot(df)
    + aes(x='Value', y='Area')
    + geom_line() + facet_wrap('Year', scales='free_x')
)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/facets/facet.py:396: PlotnineWarning: If you need more space for the y-axis tick text use ... + theme(subplots_adjust={'hspace': 0.25}). Choose an appropriate value for 'hspace'
# <ggplot: (346310617)>

# %%
(
    ggplot(df)
    + aes(x='Value', y='Area')
    + geom_line()
)
# Out:
# <ggplot: (352318419)>

# %%
df.groupby(by='Area').Value.plot(kind='barh')
# Out:
# Area
# Afghanistan                                             AxesSubplot(0.125,0.125;0.775x0.755)
# Albania                                                 AxesSubplot(0.125,0.125;0.775x0.755)
# Algeria                                                 AxesSubplot(0.125,0.125;0.775x0.755)
# Angola                                                  AxesSubplot(0.125,0.125;0.775x0.755)
# Antigua and Barbuda                                     AxesSubplot(0.125,0.125;0.775x0.755)
# Argentina                                               AxesSubplot(0.125,0.125;0.775x0.755)
# Armenia                                                 AxesSubplot(0.125,0.125;0.775x0.755)
# Australia                                               AxesSubplot(0.125,0.125;0.775x0.755)
# Austria                                                 AxesSubplot(0.125,0.125;0.775x0.755)
# Azerbaijan                                              AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
north_america = ['Canada', 'United States of America', 'Mexico', 'Guatemala', 
                'Cuba', 'Haiti']

df.Area.str.contains('Mexico').value_counts()
 
#  Dominican Republic
#  Honduras
#  Nicaragua
#  El Salvador
#  Costa Rica
#  Panama
#  Jamaica
#  Trinidad and Tobago
#  Belize
#  Bahamas
#  Barbados
#  Saint Lucia
#  Grenada
#  Antigua and Barbuda
#  Dominica
#  Saint Kitts and Nevis
# Out:
# False    3548
# True       20
# Name: Area, dtype: int64

# %%
df.Value.head(50).sort_values().plot(kind='barh', x='Area', y='Year')
# Out:
# <AxesSubplot:>

# %%
df.groupby(by='Area').Value.mean().sort_values(ascending=False).head(10)
# Out:
# Area
# Iceland                     68.4245
# China, Hong Kong SAR        63.5475
# Israel                      62.6170
# Lithuania                   59.7780
# Finland                     58.3270
# Norway                      57.3530
# Portugal                    56.8575
# United States of America    55.8310
# Luxembourg                  55.8220
# Denmark                     55.7820
# Name: Value, dtype: float64

# %%
df.groupby(by='Area').Value.mean().sort_values(ascending=False).tail(10)
# Out:
# Area
# Central African Republic            25.282000
# Congo                               24.578500
# Haiti                               24.169000
# Mozambique                          23.073500
# Madagascar                          22.292500
# Zimbabwe                            22.097000
# Guinea-Bissau                       21.679500
# Liberia                             20.008500
# Burundi                             19.940833
# Democratic Republic of the Congo    13.299000
# Name: Value, dtype: float64

# %%
df.groupby(by='Area').Value.mean().round().sort_values(ascending=True)
# Out:
# Area
# Democratic Republic of the Congo                        13.0
# Liberia                                                 20.0
# Burundi                                                 20.0
# Zimbabwe                                                22.0
# Guinea-Bissau                                           22.0
# Madagascar                                              22.0
# Mozambique                                              23.0
# Haiti                                                   24.0
# Central African Republic                                25.0
# Congo                                                   25.0
# Sierra Leone                                            25.0
# Uganda                                                  26.0
# Angola                                                  26.0
# Sao Tome and Principe                                   27.0
# Timor-Leste                                             27.0
# ...

# %%
df.groupby(by='Area').Value.mean().round().head(10).hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Year', y='Value', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
# df[df.Area.isin(north_america)].plot(x='Year', y='Value')

# %%
df[df.Area.isin(north_america)].groupby(by='Year').Value.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
north_america = ['Canada', 'United States of America', 'Mexico', 'Guatemala', 
                'Cuba', 'Haiti', 'Dominican Republic', 'Honduras', 'Nicaragua',
                 'El Salvador', 'Costa Rica', 'Panama', 'Jamaica', 'Trinidad and Tobago',
                 'Belize', 'Bahamas', 'Barbados', 'Saint Lucia', 'Grenada', 'Antigua and Barbuda',
                 'Dominica', 'Saint Kitts and Nevis']

# %%
africa = ['Algeria', 'Egypt', 'Libyan Arab Jamahiriya', 'Morocco', 'Tunisia', 'Western Sahara', 'Burundi',
          'Comoros', 'Djibouti', 'Eritrea', 'Ethiopia', 'Kenya', 'Madagascar', 'Malawi', 'Mauritius',
          'Mayotte', 'Mozambique', 'Réunion', 'Rwanda', 'Somalia', 'Sudan', 'Uganda', 'United Republic of Tanzania',
          'Zambia', 'Zimbabwe', 'Angola', 'Cameroon', 'Central African Republic', 'Chad', 'Congo', 'Democratic Republic of the Congo',
          'Equatorial Guinea', 'Gabon', 'Sao Tome and Principe', 'Botswana', 'Lesotho', 'Namibia', 'South Africa',
          'Swaziland', 'Benin', 'Burkina Faso', 'Cape Verde', "Côte d'Ivoire", 'Gambia', 'Ghana', 'Guinea',
          'Guinea-Bissau', 'Liberia', 'Mali', 'Mauritania', 'Niger', 'Nigeria', 'Senegal', 'Sierra Leone', 'Togo']

# %%
oceania = ['Fiji', 'French Polynesia', 'Guam', 'Micronesia (Federated States of)', 'New Caledonia',
           'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Vanuatu', 'New Zealand', 'Australia']

# %%
asia = ['Kazakhstan', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'China',
        'China, Hong Kong Special Administrative Region', 'China, Macao Special Administrative Region',
        "Democratic People's Republic of Korea", 'Mongolia', 'Republic of Korea', 'Brunei Darussalam',
        'Cambodia', 'Indonesia', "Lao People's Democratic Republic", 'Malaysia', 'Myanmar', 'Philippines',
        'Singapore', 'Thailand', 'Timor-Leste', 'Viet Nam', 'Afghanistan', 'Bangladesh', 'Bhutan',
        'India', 'Iran (Islamic Republic of)', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka', 'Armenia', 
        'Azerbaijan', 'Bahrain', 'Cyprus', 'Georgia', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 
        'Oman', 'Qatar', 'Saudi Arabia', 'Syrian Arab Republic', 'Turkey', 'United Arab Emirates', 
        'Yemen', 'Japan']

# %%
south_america = ['Argentina', 'Bolivia (Plurinational State of)', 'Brazil', 'Chile', 'Colombia',
                 'Ecuador', 'French Guiana', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay',
                 'Venezuela (Bolivarian Republic of)']

# %%
europe = ['Albania', 'Belarus', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czech Republic',
          'Estonia', 'Greece', 'Hungary', 'Latvia', 'Lithuania', 'Montenegro', 'Poland', 'Republic of Moldova',
          'Romania', 'Russian Federation', 'Serbia', 'Slovakia', 'Slovenia', 'North Macedonia', 'Ukraine',
          'Austria', 'Belgium', 'Channel Islands', 'Denmark', 'Finland', 'France', 'Germany', 'Iceland',
          'Ireland', 'Italy', 'Luxembourg', 'Malta', 'Netherlands', 'Norway', 'Portugal', 'Spain', 'Sweden',
          'Switzerland', 'United Kingdom of Great Britain and Northern Ireland']

# %%
df.loc[df.Area.isin(north_america), "continent"] = 'North America'

# %%
df.loc[df.Area.isin(africa), "continent"] = 'Africa'

# %%
df.loc[df.Area.isin(europe), "continent"] = 'Europe'

# %%
df.loc[df.Area.isin(asia), "continent"] = 'Asia'

# %%
df.loc[df.Area.isin(south_america), "continent"] = 'South America'

# %%
df.loc[df.Area.isin(oceania), "continent"] = 'Oceania'

# %%
df.groupby(by='continent').Value.mean().plot()
# df[df.Area.isin(north_america)].groupby(by='Year').Value.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.groupby(by='continent').Value.mean().plot(kind='area', stacked=True)
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
df.plot.area(x='continent', y='Value')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
df.groupby(['continent', 'Year']).Value.mean().plot(kind='bar', color='gray')
# Out:
# <AxesSubplot:xlabel='continent,Year'>

# %%
df.groupby(by='Year').Value.mean().plot(kind='bar', x='continent', color='gray')
# Out:
# <AxesSubplot:xlabel='Year'>
