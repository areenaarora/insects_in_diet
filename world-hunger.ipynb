# %% [markdown]
# This project looks at how efficiently and sustainably insect-based diets can save world hunger. The first steps in the analysis is to look at world hunger projections

# %% [markdown]
# Data source: [Global Hunger Index, from WHO](https://www.globalhungerindex.org/download/all.html)

# %%
import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_excel('world_hunger_index.xlsx')

# %%
# df['2012'] = df['2012'].astype(float, errors = 'raise')
# df['2013'] = df['2013'].astype(float, errors = 'raise')
# df['2014'] = df['2014'].astype(float, errors = 'raise')
# df['2015'] = df['2015'].astype(float, errors = 'raise')
# df['2016'] = df['2016'].astype(float, errors = 'raise')
# df['2017'] = df['2017'].astype(float, errors = 'raise')
# df['2018'] = df['2018'].astype(float, errors = 'raise')
# df['2019'] = df['2019'].astype(float, errors = 'raise')
# df['2020'] = df['2020'].astype(float, errors = 'raise')

# %%
df = df.rename(columns={'undernourished_pct': '2000-2002', 'Unnamed: 2': '2005-2007', 'Unnamed: 3': '2011-2013', 'Unnamed: 4': '2018-2020'})

# %%
df = df.iloc[1:]
df
# Out:
#                           country 2000-2002 2005-2007 2011-2013 2018-2020
# 1                     Afghanistan      47.8      33.3      28.2      25.6
# 2                         Albania       4.9       8.8       3.5       3.9
# 3                         Algeria         8       6.4       3.3       2.5
# 4                          Angola      67.5      49.3      16.3      17.3
# 5                       Argentina         3       3.4       3.1       3.9
# 6                         Armenia      26.1       9.3       3.6       3.4
# 7                      Azerbaijan        17       2.8       2.5       2.5
# 8                         Bahrain         —         —         —         —
# 9                      Bangladesh      15.9      13.8      15.5       9.7
# 10                        Belarus       2.5       2.5       2.5       2.5
# 11                          Benin      17.2        11       7.9       7.6
# 12                         Bhutan         —         —         —         —
# ...

# %%
df = df[df['2000-2002'] != '—']
df
# Out:
#                           country 2000-2002 2005-2007 2011-2013 2018-2020
# 1                     Afghanistan      47.8      33.3      28.2      25.6
# 2                         Albania       4.9       8.8       3.5       3.9
# 3                         Algeria         8       6.4       3.3       2.5
# 4                          Angola      67.5      49.3      16.3      17.3
# 5                       Argentina         3       3.4       3.1       3.9
# 6                         Armenia      26.1       9.3       3.6       3.4
# 7                      Azerbaijan        17       2.8       2.5       2.5
# 9                      Bangladesh      15.9      13.8      15.5       9.7
# 10                        Belarus       2.5       2.5       2.5       2.5
# 11                          Benin      17.2        11       7.9       7.6
# 13   Bolivia (Plurinat. State of)      27.9      24.6      16.5      12.6
# 14           Bosnia & Herzegovina       3.2       2.5       2.5       2.5
# ...

# %%
df.to_csv('hunger_index_cleaned.csv')
