# %%
import pandas as pd
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# Source: [Sustainable Development Goals, indicators, FAO](https://www.fao.org/sustainable-development-goals/indicators/211/en/)

# %%
df = pd.read_excel('undernourish_millions_fao.xlsx')

# %%
df
# Out:
#                                                location  year  \
# 0                                                 World  2000
# 1                                                 World  2001
# 2                                                 World  2002
# 3                                                 World  2003
# 4                                                 World  2004
# 5                                                 World  2005
# 6                                                 World  2006
# 7                                                 World  2007
# 8                                                 World  2008
# 9                                                 World  2009
# 10                                                World  2010
# 11                                                World  2011
# 12                                                World  2012
# 13                                                World  2013
# ...

# %%
continents = ['Europe', 'Asia', 'North America', 'Africa', 'South America', 'Oceania', 'Antarctica']

# continents = ['World']

# %%
df[df['location'].str.contains('World')].plot(x='year', y='undernourished_in_millions', kind='bar', color='red')
# , 'Asia', 'North America', 'Africa', 'South America', 'Oceania', 'Antarctica)]
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df[df['location'].str.contains('Asia')]
# Out:
#                                                location  year  \
# 406                                        Eastern Asia  2000
# 407                                        Eastern Asia  2001
# 408                                        Eastern Asia  2002
# 409                                        Eastern Asia  2003
# 410                                        Eastern Asia  2004
# 411                                        Eastern Asia  2005
# 412                                        Eastern Asia  2006
# 413                                        Eastern Asia  2007
# 414                                        Eastern Asia  2008
# 415                                        Eastern Asia  2009
# 416                                        Eastern Asia  2010
# 417                                        Eastern Asia  2011
# 418                                        Eastern Asia  2012
# 419                                        Eastern Asia  2013
# ...

# %%
# df.groupby(by='location').undernourished_in_millions.value_counts().plot(kind='bar')

# %%
df.value_counts('undernourished_in_millions')
# Out:
# undernourished_in_millions
# N                   1115
# <0.1                 398
# 0.3                  156
# 0.2                  136
# 0.5                   76
# 0.4                   65
# 0.1                   62
# 0.6                   58
# 1.3                   46
# 1.6                   46
# 1.2                   43
# 1.7                   43
# 1.4                   37
# 1.8                   36
# 1.5                   34
# 0.7                   33
# 2.4                   33
# 0.8                   32
# 1.1                   31
# 2.3                   27
# 1.9                   27
# 2.2                   27
# 2.5                   25
# 2.1                   25
# 2                     25
# 1                     20
# 2.6                   20
# 2.8                   19
# 0.9                   17
# 4.4                   16
# 3.1                   15
# 3.7                   15
# 2.7                   14
# 10.3                  14
# 5.7                   13
# ...
